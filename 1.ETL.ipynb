# %%
import pandas as pd
import numpy as np

# %%
report = pd.read_csv("AccidentesAviones.csv")

# %%
report.head()
# Out:
#    Unnamed: 0               fecha HORA declarada
# 0           0  September 17, 1908           1718  \
# 1           1  September 07, 1909              ?
# 2           2       July 12, 1912           0630
# 3           3     August 06, 1913              ?
# 4           4  September 09, 1913           1830
#
#                                  Ruta                OperadOR flight_no
# 0                 Fort Myer, Virginia    Military - U.S. Army         ?  \
# 1             Juvisy-sur-Orge, France                       ?         ?
# 2           Atlantic City, New Jersey    Military - U.S. Navy         ?
# 3  Victoria, British Columbia, Canada                 Private         ?
# 4                  Over the North Sea  Military - German Navy         ?
#
#            route                 ac_type registration cn_ln all_aboard
# 0  Demonstration        Wright Flyer III            ?     1          2  \
# 1       Air show          Wright Byplane          SC1     ?          1
# ...

# %%
report.tail()
# Out:
#       Unnamed: 0           fecha HORA declarada                        Ruta
# 5003        5003  March 28, 2021           1835          Near Butte, Alaska  \
# 5004        5004    May 21, 2021           1800        Near Kaduna, Nigeria
# 5005        5005   June 10, 2021           0800  Near Pyin Oo Lwin, Myanmar
# 5006        5006   July 04, 2021          11:30  Patikul, Sulu, Philippines
# 5007        5007   July 06, 2021           1500              Palana, Russia
#
#                              OperadOR flight_no                         route
# 5003                Soloy Helicopters         ?           Sightseeing Charter  \
# 5004    Military - Nigerian Air Force         ?                             ?
# 5005     Military - Myanmar Air Force         ?          Naypyidaw - Anisakan
# 5006  Military - Philippine Air Force         ?  Cagayan de Oro-Lumbia - Jolo
# 5007    Kamchatka Aviation Enterprise       251        Petropavlovsk - Palana
#
# ...

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5008 non-null   int64
#  1   fecha                   5008 non-null   object
#  2   HORA declarada          5008 non-null   object
#  3   Ruta                    5008 non-null   object
#  4   OperadOR                5008 non-null   object
#  5   flight_no               5008 non-null   object
#  6   route                   5007 non-null   object
#  7   ac_type                 5008 non-null   object
#  8   registration            5008 non-null   object
#  9   cn_ln                   5008 non-null   object
#  10  all_aboard              5008 non-null   object
#  11  PASAJEROS A BORDO       5008 non-null   object
#  12  crew_aboard             5008 non-null   object
#  13  cantidad de fallecidos  5008 non-null   object
# ...

# %% [markdown]
# 1.

# %%
#quitar las columnas que no se van a usar
report.drop(columns=['Unnamed: 0', 'flight_no', 'registration', 'cn_ln', 'ground', 'summary', 
                            'ac_type', 'route', 'OperadOR', 'Ruta','HORA declarada'], inplace=True)

# %%
#obtiene el anio de cada accidente
report["year"] = pd.to_datetime(report["fecha"]).dt.year

#selecciona los accidentes que pasaron desde el 2000 en adelante
report = report[report["year"] >= 2000]

# %%
report = report.drop("fecha", axis=1)

# %%
report.isnull().sum()
# Out:
# all_aboard                0
# PASAJEROS A BORDO         0
# crew_aboard               0
# cantidad de fallecidos    0
# passenger_fatalities      0
# crew_fatalities           0
# year                      0
# dtype: int64

# %%
report = report.replace(to_replace="?", value=np.nan)

# %%
report.reset_index(drop=True, inplace=True)

# %%
report = report.rename(columns={'all_aboard': 'total_abordo', 'PASAJEROS A BORDO': 'pasajeros_abordo',
                                'crew_aboard' : 'personal_abordo','cantidad de fallecidos':'total_fallecidos',
                                'passenger_fatalities' :'pasajeros_fallecidos', 'crew_fatalities':'personal_fallecido','year':'anio'})

# %%
report
# Out:
#     total_abordo pasajeros_abordo personal_abordo total_fallecidos
# 0             16               13               3                1  \
# 1             10                7               3               10
# 2             41               38               3               22
# 3             20               17               3                5
# 4            179              169              10              169
# ..           ...              ...             ...              ...
# 755            6                5               1                5
# 756           11                7               4               11
# 757           14               12               2               12
# 758           96               88               8               50
# 759           28               22               6               28
#
#     pasajeros_fallecidos personal_fallecido  anio
# 0                      1                  0  2000
# 1                      7                  3  2000
# ...

# %%
report1 = report[(report["anio"] >= 2000) & (report["anio"] < 2011)]
report2 = report[(report["anio"] >= 2011) & (report["anio"] <= 2021)]

# %%
report1
# Out:
#     total_abordo pasajeros_abordo personal_abordo total_fallecidos
# 0             16               13               3                1  \
# 1             10                7               3               10
# 2             41               38               3               22
# 3             20               17               3                5
# 4            179              169              10              169
# ..           ...              ...             ...              ...
# 542           21               17               4               21
# 543           10              NaN             NaN                7
# 544            8                0               8                8
# 545          169              160               9                2
# 546           22               19               3               22
#
#     pasajeros_fallecidos personal_fallecido  anio
# 0                      1                  0  2000
# 1                      7                  3  2000
# ...

# %%
report2
# Out:
#     total_abordo pasajeros_abordo personal_abordo total_fallecidos
# 547          124              116               8                3  \
# 548          105               93              12               77
# 549            9                7               2                9
# 550           12               10               2                6
# 551           14               12               2               14
# ..           ...              ...             ...              ...
# 755            6                5               1                5
# 756           11                7               4               11
# 757           14               12               2               12
# 758           96               88               8               50
# 759           28               22               6               28
#
#     pasajeros_fallecidos personal_fallecido  anio
# 547                    3                  0  2011
# 548                   65                 12  2011
# ...

# %%
report.to_csv("Accidentes_2000_al_actual.csv")
report1.to_csv("Accidentes_2000-2010.csv")
report2.to_csv("Accidentes_2011-2021.csv")
